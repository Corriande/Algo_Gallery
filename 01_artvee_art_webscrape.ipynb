# %% [markdown]
# # 01_artvee_art_webscrape
#
# ## Notebook 1/4
#
# ## Gabriel del Valle
# ## 10/08/24
# ## NYC DATA SCIENCE ACADEMY
#
#
# ## The purpose of this project is to create a simplified context to apply content recommendation techniques in an interactive Shiny app.
#
#
# ### Try out the full interactive app! Read the Home page for project details and instructions
#
# https://gabrielxdelvalle.shinyapps.io/algo_gallery/
#
# ### Read the full project details on the blog post:
#
# https://nycdatascience.com/blog/student-works/clustering-artworks-by-ai-quantified-visual-qualities-content-recommendation-app/
#
# ### For any questions or inquieries about this project please feel free to reach out on Linkedin:
#
# www.linkedin.com/in/gabriel-del-valle-147616152
#
#
# ## This first notebook is used to webscrape the public domain modern artworks that will serve as the 'content' in the content recommendation system.
#
# - The source of public domain art is Artvee.com
#
#
# - Images must be saved to user's local files as Artvee provides only temporary image links for the images they host.
#
# - In order to host the images on my shiny app, I uploaded them to a Github repository. This is a way to create accessible image weblinks for free, but limits the number of images that can be hosted to 1000.
#
#
# ## Notebook Structure
#
# ### 1. Scrape webdata from Artvee
# ### 2. Clean data about artwork and artist
# ### 3. Remove rows with an invalid filename from artworks datset
# ### 4. Remove rows with missing data
# ### 5. Create live image links for each filepath based on github repository

# %%
import requests
from bs4 import BeautifulSoup
import os
import pandas as pd
import numpy
import re

# %%
from PIL import Image
from io import BytesIO

# %% [markdown]
# # 1. The following loop uses the BeautifulSoup library to scrape both images and information about the artwork from Artvee.
#
# ## Images are stored in a designated directory on user's computer
#
# ## Artwork data is stored and organized in artworks_data_all
#
# ## In the case that an image fails to be requested or downloaded, its information will be added to broken_images

# %%
artworks_data_all = []

broken_images = []

total_index = 0

#set an output directory for downloaded images
os.makedirs('artvee_downloads_all3', exist_ok=True)


#There are 70 artworks per page
#The following range sets the number of pages to scrape
for n in range(1, 20):

    url = f"https://artvee.com/c/abstract/page/{n}/?per_page=70"

    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Loop through each artwork on the page
    for art_item in soup.find_all('div', class_='product-grid-item'):
        
        # Extract the image URL
        image_url = art_item.find('img')['data-src']
        
        
        
        # Extract the title and year
        title_year = art_item.find('h3', class_='product-title').text.strip()
        
        # Split the title_year into title and year
        if '(' in title_year and ')' in title_year:
            title, year = title_year.rsplit('(', 1)
            year = year.strip(') ')
            title = title.strip()
        else:
            title = title_year
            year = 'Unknown'  # In case the year is not present in the title


       

        # Extract the artist information
        artist_info = art_item.find('div', class_='woodmart-product-brands-links').text.strip()

        # Check if the artist_info contains the expected pattern " ("
        if ' (' in artist_info:
            artist_name, artist_details = artist_info.split(' (', 1)
            nationality, lifespan = artist_details.rsplit(',', 1)
            nationality = nationality.strip()
            lifespan = lifespan.strip(')')
        else:
            artist_name = artist_info  # If no " (" pattern, assume the whole string is the artist's name
            nationality = 'Unknown'
            lifespan = 'Unknown'

       
        
        
        # Download the image
        try:
            img_data = requests.get(image_url).content
            img = Image.open(BytesIO(img_data))
            img.verify()  # Check the integrity of the image

            # Save the image if verified
            img_name = os.path.join('artvee_downloads_all3', f"{title_year}.jpg")
            with open(img_name, 'wb') as handler:
                handler.write(img_data)

            # Append the data as a dictionary to the list
            artworks_data_all.append({
                "Title": title,
                "Year": year,
                "Artist": artist_name,
                "Nationality": nationality,
                "Lifespan": lifespan,
                "Image_URL": image_url,
                "Image_path": f"{title_year}.jpg",
                "total_index": total_index
            })

        except (requests.RequestException, IOError):
            # If there's an error with the request or image integrity, log it as broken
            broken_images.append({
                "Title": title,
                "Year": year,
                "Artist": artist_name,
                "Nationality": nationality,
                "Lifespan": lifespan,
                "Image_URL": image_url,
            })
            
        total_index+=1
            
            
        
        
        
        
            
artworks_all = pd.DataFrame(artworks_data_all)
            
brocken_images_df = pd.DataFrame(broken_images)

# %%
print(len(artworks_all))
print(len(brocken_images_df))
# Out:
# 1330
# 0

# %%
#artworks_all.to_csv('modern_scraping.csv', index=False)

# %% [markdown]
# ## 2. Clean data about artwork and artsit
#
# When I first started this project I considered using data such as the artist's Nationality and the year of the artwork as part of the analysis, but then decided the connection to user preferences would be neglible.
#
# ### Cleaning the scraped data about the artwork and artist is not necessary for the visual analysis which constitutes the rest of the project, but is part of making the app look consistent and professional.
#
# Regular expressions and string manipulation are used to standardize the Year column, and turn the Lifespan column into just a Birth column (to account for many cases where a death year is unknown).

# %%
test = artworks_all.copy()

# %%
def clean_lifespan(lifespan):
    # Normalize the lifespan string by replacing any known zero-width spaces and non-breaking spaces
    lifespan = lifespan.replace('\u2009', ' ').replace('\u200b', '').strip()
    
    # Remove prefixes like "ca", "c.", "circa" and extra spaces
    lifespan = re.sub(r'^(ca\.?|c\.?|circa)\s*', '', lifespan, flags=re.IGNORECASE)
    
    # Handle centuries
    if "Century" in lifespan or "century" in lifespan:
        if "20th" in lifespan:
            lifespan = "1900 - 2000"
        elif "19th" in lifespan:
            lifespan = "1800 - 1900"
        # Add more cases as needed
    
    # Handle birth without death
    if lifespan.startswith("b."):
        birth_year = lifespan.replace("b.", "").strip()
        return birth_year, "Unknown"
    
    # Handle birth and death with an error or missing death
    if lifespan.endswith("-") or lifespan.endswith("\u2013"):  # Also handle en dash
        birth_year = lifespan.rstrip("-\u2013").strip()
        return birth_year, "Unknown"
    
    # Handle typical format and split, including en dash
    if "-" in lifespan or "\u2013" in lifespan:
        birth_year, death_year = re.split(r"[-\u2013]", lifespan)  # Split by hyphen or en dash
        birth_year = birth_year.strip()
        death_year = death_year.strip()
        return birth_year, death_year
    
    # Handle cases like "Unknown"
    if lifespan.lower() == "unknown":
        return "Unknown", "Unknown"
    
    # If the format is not recognized, return as unknown
    return "Unknown", "Unknown"

# %%
# Apply the function to the Lifespan column
test['Birth'], test['Death'] = zip(*test['Lifespan'].apply(clean_lifespan))

# Convert Birth and Death columns to numeric, handling 'Unknown' with NaN
test['Birth'] = pd.to_numeric(test['Birth'], errors='coerce').astype('Int64')
test['Death'] = pd.to_numeric(test['Death'], errors='coerce').astype('Int64')

# Drop the original Lifespan column if no longer needed
#modern_gallery_full.drop(columns=['Lifespan'], inplace=True)

# %%
test_lifespan = test[test['Lifespan'] != "Unknown"]
test_lifespan2 = test_lifespan[test_lifespan['Birth'].isna()]
test_lifespan2
# Out:
# Empty DataFrame
# Columns: [Title, Year, Artist, Nationality, Lifespan, Image_URL, Image_path, total_index, Birth, Death]
# Index: []

# %%
test_lifespan3 = test_lifespan[test_lifespan['Death'].isna()]
test_lifespan3['Lifespan'].unique()
# Out:
# array([' b. 1941', ' 1963-', ' 1923 - ', ' 1913-?', ' b. 1940',
#        ' 1928 - ', ' b. 1952'], dtype=object)

# %% [markdown]
# Now the lifespan, birth, and death columns are perfectly filtered. I can remove the rows that don't have a death since they could interfere with analysis

# %%
def clean_year(year):
    # Remove \xa0 (non-breaking space) and other unwanted characters
    year = year.replace('\xa0', ' ').strip()
    
    # Handle simple single year case
    if re.match(r'^\d{4}$', year):
        return int(year)
    
    # Handle two years separated by '-' or 'to', including two-digit year differences
    match = re.match(r'^(\d{4})\s*(?:-|to|–)\s*(\d{2,4})$', year)
    if match:
        first_year = int(match.group(1))
        second_year = match.group(2)
        if len(second_year) == 2:
            # Convert two-digit year to full year
            second_year = int(str(first_year)[:2] + second_year)
        else:
            second_year = int(second_year)
        return second_year  # Return the latter year
    
    # Handle cases like 'ca. 1808–10', 'circa 1922', 'around 1923', etc.
    match = re.match(r'^(?:ca\.?|circa|around|from|between|before|c\.)\s*(\d{4})(?:\s*(?:-|to|and|until)\s*(\d{2,4}))?', year, re.IGNORECASE)
    if match:
        first_year = int(match.group(1))
        if match.group(2):
            second_year = match.group(2)
            if len(second_year) == 2:
                second_year = int(str(first_year)[:2] + second_year)
            else:
                second_year = int(second_year)
            return second_year
        return first_year
    
    # Handle cases like 'between 1919 and 1921' by reducing to the latter year
    match = re.match(r'^between\s*(\d{4})\s*and\s*(\d{4})$', year, re.IGNORECASE)
    if match:
        return int(match.group(2))
    
    # Handle 'before 1921' by using the year itself
    match = re.match(r'^before\s*(\d{4})$', year, re.IGNORECASE)
    if match:
        return int(match.group(1))
    
    # Handle 'ca 1880', 'ca 1916', etc.
    match = re.match(r'^(?:ca|c\.)\s*(\d{4})$', year, re.IGNORECASE)
    if match:
        return int(match.group(1))

    # Handle non-numeric or unknown year cases
    if year.lower() == "unknown" or not re.search(r'\d{4}', year):
        return "Unknown"
    
    return "Unknown"

# %%
# Apply the cleaning function to the Year column
test['Cleaned_Year'] = test['Year'].apply(clean_year)

# Convert to integer where possible, with NaN for unknowns
test['Cleaned_Year'] = pd.to_numeric(test['Cleaned_Year'], errors='coerce').astype('Int64')

# %%
test_year = test[test['Cleaned_Year'] != "Unknown"]
test_year2 = test_year[test_year['Cleaned_Year'].isna()]
test_year2
# Out:
# Empty DataFrame
# Columns: [Title, Year, Artist, Nationality, Lifespan, Image_URL, Image_path, total_index, Birth, Death, Cleaned_Year]
# Index: []

# %%
test[test['Lifespan']== "Unknown"]
# Out:
#                                                   Title               Year  \
# 6         Meinem Theuren Vater and Meiner Theuren Mater               1818
# 29    Textile Design with Vertical Strips of Pearls ...               1840
# 33              Design for a Textile with Stylized Leaf               1911
# 53                                   Kúpalisko v Hévízi          1930–1939
# 68                                      Universal Wheel           ca. 1780
# 92                                              Gavotte               1912
# 112                                               Ariel            1911–13
# 116                                               Adria            1910–11
# 203                                            Untitled            Unknown
# 255                        Sommerwinde (Summer Wind) II               1922
# 267                                          Salambo II            1910–15
# 277                                              Aussee            1911–14
# 297   Art – Goût – Beauté, Feuillets de l’ élégance ...            Unknown
# 302                                   Prolog (Prologue)               1922
# 332                                 Trellis-work Design            1815–22
# 407   Art – Goût – Beauté, Feuillets de l’ élégance ...            Unknown
# 485                          Four bands on black ground  late 19th century
# 496                       Sommerwinde (Summer Wind) III               1922
# 577                                     Creations Pl.09               1945
# 615                     Fish Design for a Ceramic Plate      ca. 1930-1939
# 660                          Nude Woman Fixing Her Hair            Unknown
# 743          Stylized floral design for printed textile          1800–1818
# 745                                   Abstraktne motiiv            Unknown
# 754                                   Temple of the Sun           ca. 1780
# 756                                     Creations Pl.20               1945
# 760                       Abstract-futurist Composition            c. 1912
# 768                    Wetterleuchten (Sheet Lightning)            1913–22
# 824                                         Design—Gray            Unknown
# 858                    Wetterleuchten (Sheet Lightning)            1913–22
# 894                                               Lenox          1936-1940
# 900                   Floral design for printed textile          1800–1818
# 927                                        Mount Vernon            Unknown
# 937                         Design for a Printed Fabric            1820–40
# 938                                         Female Nude            Unknown
# 981        Floral design for printed textile Pl XXXVIII          1800–1818
# 997                     Trade Card, Manhattan Watch Co.         after 1884
# 1023                                          Bullfight               1912
# 1038                                    Creations Pl.11               1945
# 1041  Decorated Initial ‘L’ with Flowers from a Choi...          1300–1399
# 1100  Textile Design with Undulating Vertical Strips...               1840
# 1140                                           Untitled            Unknown
# 1158                                              Flora               1911
# 1170                           Schattenriß (Silhouette)            1912–19
# 1185  Vertical and Horizontal Rows of Stylized Bulle...               1840
# 1303                                             Marina            1911–12
# 1323                       Chinese Garden with Fountain           ca. 1780
#
#                       Artist Nationality Lifespan  \
# 6                  Anonymous     Unknown  Unknown
# 29                 Anonymous     Unknown  Unknown
# 33                 Anonymous     Unknown  Unknown
# 53               József Egry     Unknown  Unknown
# 68                 Anonymous     Unknown  Unknown
# 92                 Anonymous     Unknown  Unknown
# 112                Anonymous     Unknown  Unknown
# 116                Anonymous     Unknown  Unknown
# 203                Anonymous     Unknown  Unknown
# 255                Anonymous     Unknown  Unknown
# 267                Anonymous     Unknown  Unknown
# 277                Anonymous     Unknown  Unknown
# 297                Anonymous     Unknown  Unknown
# 302                Anonymous     Unknown  Unknown
# 332                Anonymous     Unknown  Unknown
# 407                Anonymous     Unknown  Unknown
# 485                Anonymous     Unknown  Unknown
# 496                Anonymous     Unknown  Unknown
# 577          Jef de Schilder     Unknown  Unknown
# 615             Holcha Krake     Unknown  Unknown
# 660       Joseph C. Claghorn     Unknown  Unknown
# 743                Anonymous     Unknown  Unknown
# 745              Ülo Sooster     Unknown  Unknown
# 754                Anonymous     Unknown  Unknown
# 756          Jef de Schilder     Unknown  Unknown
# 760             Chris Lanooy     Unknown  Unknown
# 768                Anonymous     Unknown  Unknown
# 824     Lowell Daunt Collins     Unknown  Unknown
# 858                Anonymous     Unknown  Unknown
# 894   Albert Eugene Gallatin     Unknown  Unknown
# 900                Anonymous     Unknown  Unknown
# 927       Joseph C. Claghorn     Unknown  Unknown
# 937                Anonymous     Unknown  Unknown
# 938          Charles Malfray     Unknown  Unknown
# 981                Anonymous     Unknown  Unknown
# 997                Anonymous     Unknown  Unknown
# 1023          Boris Anisfeld     Unknown  Unknown
# 1038         Jef de Schilder     Unknown  Unknown
# 1041               Anonymous     Unknown  Unknown
# 1100               Anonymous     Unknown  Unknown
# 1140               Anonymous     Unknown  Unknown
# 1158               Anonymous     Unknown  Unknown
# 1170               Anonymous     Unknown  Unknown
# 1185               Anonymous     Unknown  Unknown
# 1303               Anonymous     Unknown  Unknown
# 1323               Anonymous     Unknown  Unknown
#
#                                    Image_URL  \
# 6     https://mdl.artvee.com/ft/104183ab.jpg
# 29    https://mdl.artvee.com/ft/104283ab.jpg
# 33    https://mdl.artvee.com/ft/104116ab.jpg
# 53    https://mdl.artvee.com/ft/912628ab.jpg
# 68    https://mdl.artvee.com/ft/103972ab.jpg
# 92    https://mdl.artvee.com/ft/103927ab.jpg
# 112   https://mdl.artvee.com/ft/104112ab.jpg
# 116   https://mdl.artvee.com/ft/103891ab.jpg
# 203   https://mdl.artvee.com/ft/912744ab.jpg
# 255   https://mdl.artvee.com/ft/103955ab.jpg
# 267   https://mdl.artvee.com/ft/103947ab.jpg
# 277   https://mdl.artvee.com/ft/103901ab.jpg
# 297   https://mdl.artvee.com/ft/103167ab.jpg
# 302   https://mdl.artvee.com/ft/103940ab.jpg
# 332   https://mdl.artvee.com/ft/104010ab.jpg
# 407   https://mdl.artvee.com/ft/103166ab.jpg
# 485   https://mdl.artvee.com/ft/104006ab.jpg
# 496   https://mdl.artvee.com/ft/103956ab.jpg
# 577   https://mdl.artvee.com/ft/107595ab.jpg
# 615   https://mdl.artvee.com/ft/912763ab.jpg
# 660   https://mdl.artvee.com/ft/912775ab.jpg
# 743   https://mdl.artvee.com/ft/104198ab.jpg
# 745   https://mdl.artvee.com/ft/912071ab.jpg
# 754   https://mdl.artvee.com/ft/103967ab.jpg
# 756   https://mdl.artvee.com/ft/107606ab.jpg
# 760   https://mdl.artvee.com/ft/912597ab.jpg
# 768   https://mdl.artvee.com/ft/104292ab.jpg
# 824   https://mdl.artvee.com/ft/911471ab.jpg
# 858   https://mdl.artvee.com/ft/104291ab.jpg
# 894   https://mdl.artvee.com/ft/911403ab.jpg
# 900   https://mdl.artvee.com/ft/104168ab.jpg
# 927   https://mdl.artvee.com/ft/912774ab.jpg
# 937   https://mdl.artvee.com/ft/103914ab.jpg
# 938   https://mdl.artvee.com/ft/911563ab.jpg
# 981   https://mdl.artvee.com/ft/104167ab.jpg
# 997   https://mdl.artvee.com/ft/104009ab.jpg
# 1023  https://mdl.artvee.com/ft/910752ab.jpg
# 1038  https://mdl.artvee.com/ft/107597ab.jpg
# 1041  https://mdl.artvee.com/ft/100613ab.jpg
# 1100  https://mdl.artvee.com/ft/104278ab.jpg
# 1140  https://mdl.artvee.com/ft/101885ab.jpg
# 1158  https://mdl.artvee.com/ft/103922ab.jpg
# 1170  https://mdl.artvee.com/ft/103950ab.jpg
# 1185  https://mdl.artvee.com/ft/104290ab.jpg
# 1303  https://mdl.artvee.com/ft/104182ab.jpg
# 1323  https://mdl.artvee.com/ft/103910ab.jpg
#
#                                              Image_path  total_index  Birth  \
# 6     Meinem Theuren Vater and Meiner Theuren Mater ...            6   <NA>
# 29    Textile Design with Vertical Strips of Pearls ...           29   <NA>
# 33    Design for a Textile with Stylized Leaf (1911)...           33   <NA>
# 53                   Kúpalisko v Hévízi (1930–1939).jpg           53   <NA>
# 68                       Universal Wheel (ca. 1780).jpg           68   <NA>
# 92                                   Gavotte (1912).jpg           92   <NA>
# 112                                 Ariel (1911–13).jpg          112   <NA>
# 116                                 Adria (1910–11).jpg          116   <NA>
# 203                                        Untitled.jpg          203   <NA>
# 255             Sommerwinde (Summer Wind) II (1922).jpg          255   <NA>
# 267                            Salambo II (1910–15).jpg          267   <NA>
# 277                                Aussee (1911–14).jpg          277   <NA>
# 297   Art – Goût – Beauté, Feuillets de l’ élégance ...          297   <NA>
# 302                        Prolog (Prologue) (1922).jpg          302   <NA>
# 332                   Trellis-work Design (1815–22).jpg          332   <NA>
# 407   Art – Goût – Beauté, Feuillets de l’ élégance ...          407   <NA>
# 485   Four bands on black ground (late 19th century)...          485   <NA>
# 496            Sommerwinde (Summer Wind) III (1922).jpg          496   <NA>
# 577                          Creations Pl.09 (1945).jpg          577   <NA>
# 615   Fish Design for a Ceramic Plate (ca. 1930-1939...          615   <NA>
# 660                      Nude Woman Fixing Her Hair.jpg          660   <NA>
# 743   Stylized floral design for printed textile (18...          743   <NA>
# 745                               Abstraktne motiiv.jpg          745   <NA>
# 754                    Temple of the Sun (ca. 1780).jpg          754   <NA>
# 756                          Creations Pl.20 (1945).jpg          756   <NA>
# 760         Abstract-futurist Composition (c. 1912).jpg          760   <NA>
# 768      Wetterleuchten (Sheet Lightning) (1913–22).jpg          768   <NA>
# 824                                     Design—Gray.jpg          824   <NA>
# 858      Wetterleuchten (Sheet Lightning) (1913–22).jpg          858   <NA>
# 894                               Lenox (1936-1940).jpg          894   <NA>
# 900   Floral design for printed textile (1800–1818).jpg          900   <NA>
# 927                                    Mount Vernon.jpg          927   <NA>
# 937           Design for a Printed Fabric (1820–40).jpg          937   <NA>
# 938                                     Female Nude.jpg          938   <NA>
# 981   Floral design for printed textile Pl XXXVIII (...          981   <NA>
# 997    Trade Card, Manhattan Watch Co. (after 1884).jpg          997   <NA>
# 1023                               Bullfight (1912).jpg         1023   <NA>
# 1038                         Creations Pl.11 (1945).jpg         1038   <NA>
# 1041  Decorated Initial ‘L’ with Flowers from a Choi...         1041   <NA>
# 1100  Textile Design with Undulating Vertical Strips...         1100   <NA>
# 1140                                       Untitled.jpg         1140   <NA>
# 1158                                   Flora (1911).jpg         1158   <NA>
# 1170             Schattenriß (Silhouette) (1912–19).jpg         1170   <NA>
# 1185  Vertical and Horizontal Rows of Stylized Bulle...         1185   <NA>
# 1303                               Marina (1911–12).jpg         1303   <NA>
# 1323        Chinese Garden with Fountain (ca. 1780).jpg         1323   <NA>
#
#       Death  Cleaned_Year
# 6      <NA>          1818
# 29     <NA>          1840
# 33     <NA>          1911
# 53     <NA>          1939
# 68     <NA>          1780
# 92     <NA>          1912
# 112    <NA>          1913
# 116    <NA>          1911
# 203    <NA>          <NA>
# 255    <NA>          1922
# 267    <NA>          1915
# 277    <NA>          1914
# 297    <NA>          <NA>
# 302    <NA>          1922
# 332    <NA>          1822
# 407    <NA>          <NA>
# 485    <NA>          <NA>
# 496    <NA>          1922
# 577    <NA>          1945
# 615    <NA>          1939
# 660    <NA>          <NA>
# 743    <NA>          1818
# 745    <NA>          <NA>
# 754    <NA>          1780
# 756    <NA>          1945
# 760    <NA>          1912
# 768    <NA>          1922
# 824    <NA>          <NA>
# 858    <NA>          1922
# 894    <NA>          1940
# 900    <NA>          1818
# 927    <NA>          <NA>
# 937    <NA>          1840
# 938    <NA>          <NA>
# 981    <NA>          1818
# 997    <NA>          <NA>
# 1023   <NA>          1912
# 1038   <NA>          1945
# 1041   <NA>          1399
# 1100   <NA>          1840
# 1140   <NA>          <NA>
# 1158   <NA>          1911
# 1170   <NA>          1919
# 1185   <NA>          1840
# 1303   <NA>          1912
# 1323   <NA>          1780

# %%
all_known = test[(test['Year'] != "Unknown") & (test['Lifespan'] != "Unknown")]
all_known
# Out:
#                                                   Title         Year  \
# 0                                          Construction         1924
# 1     Dance Abstraction; Isadora Duncan (or ‘Rhythmi...         1920
# 2                Ohne Titel; aus; ‘Die 150 Blätter’ VII         1940
# 3                          Zeilboten op een werfhelling         1906
# 4                                                   Why         1940
# ...                                                 ...          ...
# 1325  Váza s kyticí a broskve (Vase of flowers and p...         1932
# 1326                                      Self-Portrait         1928
# 1327                                               Head  before 1921
# 1328                                       Klänge Pl.13         1913
# 1329  Beethovenfries; ‘Die Sehnsucht nach Glück find...         1901
#
#                      Artist Nationality      Lifespan  \
# 0        László Moholy-Nagy   Hungarian   1895 - 1946
# 1         Abraham Walkowitz    American     1878-1965
# 2               Karl Wiener    Austrian     1901-1949
# 3              Reijer Stolk       Dutch   1896 - 1945
# 4               Karl Wiener    Austrian     1901-1949
# ...                     ...         ...           ...
# 1325             Emil Filla       Czech     1882-1953
# 1326  Ernst Ludwig Kirchner      German     1880-1938
# 1327       Gustaw Gwozdecki      Polish     1880-1935
# 1328      Wassily Kandinsky     Russian   1866 - 1944
# 1329           Gustav Klimt    Austrian     1862-1918
#
#                                    Image_URL  \
# 0     https://mdl.artvee.com/ft/101991ab.jpg
# 1     https://mdl.artvee.com/ft/106394ab.jpg
# 2     https://mdl.artvee.com/ft/104773ab.jpg
# 3     https://mdl.artvee.com/ft/103462ab.jpg
# 4     https://mdl.artvee.com/ft/104895ab.jpg
# ...                                      ...
# 1325  https://mdl.artvee.com/ft/912315ab.jpg
# 1326  https://mdl.artvee.com/ft/100178ab.jpg
# 1327  https://mdl.artvee.com/ft/106321ab.jpg
# 1328  https://mdl.artvee.com/ft/910880ab.jpg
# 1329  https://mdl.artvee.com/ft/105257ab.jpg
#
#                                              Image_path  total_index  Birth  \
# 0                               Construction (1924).jpg            0   1895
# 1     Dance Abstraction; Isadora Duncan (or ‘Rhythmi...            1   1878
# 2     Ohne Titel; aus; ‘Die 150 Blätter’ VII (1940).jpg            2   1901
# 3               Zeilboten op een werfhelling (1906).jpg            3   1896
# 4                                        Why (1940).jpg            4   1901
# ...                                                 ...          ...    ...
# 1325  Váza s kyticí a broskve (Vase of flowers and p...         1325   1882
# 1326                           Self-Portrait (1928).jpg         1326   1880
# 1327                             Head (before 1921).jpg         1327   1880
# 1328                            Klänge Pl.13 (1913).jpg         1328   1866
# 1329  Beethovenfries; ‘Die Sehnsucht nach Glück find...         1329   1862
#
#       Death  Cleaned_Year
# 0      1946          1924
# 1      1965          1920
# 2      1949          1940
# 3      1945          1906
# 4      1949          1940
# ...     ...           ...
# 1325   1953          1932
# 1326   1938          1928
# 1327   1935          1921
# 1328   1944          1913
# 1329   1918          1901
#
# [1206 rows x 11 columns]

# %%
all_known[all_known['Death'].isna()]
# Out:
#                                 Title  Year                 Artist  \
# 64                        Swan Carpet  1991           Tiit Pääsuke
# 114              Blossom in the Grass  1976           Tiit Pääsuke
# 190       Sommerlinien (Lignes d’été)  2014           Myriam Thyes
# 327   Four spaces with a broken cross  2017           Myriam Thyes
# 365                Detail of fountain  1975    Victor Alfred Lundy
# 366        Balken und gewellte Linien  2014           Myriam Thyes
# 431                    Pejzaż wiejski  1940  Kazimierz Wojtanowicz
# 630      Maastik oksaga (Autoportree)  1982           Tiit Pääsuke
# 784                          Urogallo  2013   José de Martín Simón
# 829                Laine ja Laine III  2020           Tiit Pääsuke
# 862                     Abstraktsioon  1967            Lola Liivat
# 923                             You 友  1982            André Kneib
# 1247               Küülikute jootmine  2005           Tiit Pääsuke
#
#      Nationality  Lifespan                               Image_URL  \
# 64      Estonian   b. 1941  https://mdl.artvee.com/ft/911173ab.jpg
# 114     Estonian   b. 1941  https://mdl.artvee.com/ft/911146ab.jpg
# 190        Swiss     1963-  https://mdl.artvee.com/ft/911273ab.jpg
# 327        Swiss     1963-  https://mdl.artvee.com/ft/911260ab.jpg
# 365     American   1923 -   https://mdl.artvee.com/ft/912721ab.jpg
# 366        Swiss     1963-  https://mdl.artvee.com/ft/911256ab.jpg
# 431       Polish    1913-?  https://mdl.artvee.com/ft/106569ab.jpg
# 630     Estonian   b. 1941  https://mdl.artvee.com/ft/911163ab.jpg
# 784      Spanish   b. 1940  https://mdl.artvee.com/ft/911234ab.jpg
# 829     Estonian   b. 1941  https://mdl.artvee.com/ft/911161ab.jpg
# 862     Estonian   1928 -   https://mdl.artvee.com/ft/911107ab.jpg
# 923       French   b. 1952  https://mdl.artvee.com/ft/911407ab.jpg
# 1247    Estonian   b. 1941  https://mdl.artvee.com/ft/911158ab.jpg
#
#                                       Image_path  total_index  Birth  Death  \
# 64                        Swan Carpet (1991).jpg           64   1941   <NA>
# 114              Blossom in the Grass (1976).jpg          114   1941   <NA>
# 190       Sommerlinien (Lignes d’été) (2014).jpg          190   1963   <NA>
# 327   Four spaces with a broken cross (2017).jpg          327   1963   <NA>
# 365                Detail of fountain (1975).jpg          365   1923   <NA>
# 366        Balken und gewellte Linien (2014).jpg          366   1963   <NA>
# 431                    Pejzaż wiejski (1940).jpg          431   1913   <NA>
# 630      Maastik oksaga (Autoportree) (1982).jpg          630   1941   <NA>
# 784                          Urogallo (2013).jpg          784   1940   <NA>
# 829                Laine ja Laine III (2020).jpg          829   1941   <NA>
# 862                     Abstraktsioon (1967).jpg          862   1928   <NA>
# 923                             You 友 (1982).jpg          923   1952   <NA>
# 1247               Küülikute jootmine (2005).jpg         1247   1941   <NA>
#
#       Cleaned_Year
# 64            1991
# 114           1976
# 190           2014
# 327           2017
# 365           1975
# 366           2014
# 431           1940
# 630           1982
# 784           2013
# 829           2020
# 862           1967
# 923           1982
# 1247          2005

# %% [markdown]
# Death is probably a less influential trait on the substance of the art than the birth, so it doesn't need to be included. There are no NA births that are not "Unknown".

# %%
modern_gallery = all_known.copy()
modern_gallery.drop("total_index", axis = 1, inplace = True)
modern_gallery.drop("Year", axis = 1, inplace = True)
modern_gallery = modern_gallery.rename(columns = {'Cleaned_Year': "Year"})
modern_gallery
# Out:
#                                                   Title  \
# 0                                          Construction
# 1     Dance Abstraction; Isadora Duncan (or ‘Rhythmi...
# 2                Ohne Titel; aus; ‘Die 150 Blätter’ VII
# 3                          Zeilboten op een werfhelling
# 4                                                   Why
# ...                                                 ...
# 1325  Váza s kyticí a broskve (Vase of flowers and p...
# 1326                                      Self-Portrait
# 1327                                               Head
# 1328                                       Klänge Pl.13
# 1329  Beethovenfries; ‘Die Sehnsucht nach Glück find...
#
#                      Artist Nationality      Lifespan  \
# 0        László Moholy-Nagy   Hungarian   1895 - 1946
# 1         Abraham Walkowitz    American     1878-1965
# 2               Karl Wiener    Austrian     1901-1949
# 3              Reijer Stolk       Dutch   1896 - 1945
# 4               Karl Wiener    Austrian     1901-1949
# ...                     ...         ...           ...
# 1325             Emil Filla       Czech     1882-1953
# 1326  Ernst Ludwig Kirchner      German     1880-1938
# 1327       Gustaw Gwozdecki      Polish     1880-1935
# 1328      Wassily Kandinsky     Russian   1866 - 1944
# 1329           Gustav Klimt    Austrian     1862-1918
#
#                                    Image_URL  \
# 0     https://mdl.artvee.com/ft/101991ab.jpg
# 1     https://mdl.artvee.com/ft/106394ab.jpg
# 2     https://mdl.artvee.com/ft/104773ab.jpg
# 3     https://mdl.artvee.com/ft/103462ab.jpg
# 4     https://mdl.artvee.com/ft/104895ab.jpg
# ...                                      ...
# 1325  https://mdl.artvee.com/ft/912315ab.jpg
# 1326  https://mdl.artvee.com/ft/100178ab.jpg
# 1327  https://mdl.artvee.com/ft/106321ab.jpg
# 1328  https://mdl.artvee.com/ft/910880ab.jpg
# 1329  https://mdl.artvee.com/ft/105257ab.jpg
#
#                                              Image_path  Birth  Death  Year
# 0                               Construction (1924).jpg   1895   1946  1924
# 1     Dance Abstraction; Isadora Duncan (or ‘Rhythmi...   1878   1965  1920
# 2     Ohne Titel; aus; ‘Die 150 Blätter’ VII (1940).jpg   1901   1949  1940
# 3               Zeilboten op een werfhelling (1906).jpg   1896   1945  1906
# 4                                        Why (1940).jpg   1901   1949  1940
# ...                                                 ...    ...    ...   ...
# 1325  Váza s kyticí a broskve (Vase of flowers and p...   1882   1953  1932
# 1326                           Self-Portrait (1928).jpg   1880   1938  1928
# 1327                             Head (before 1921).jpg   1880   1935  1921
# 1328                            Klänge Pl.13 (1913).jpg   1866   1944  1913
# 1329  Beethovenfries; ‘Die Sehnsucht nach Glück find...   1862   1918  1901
#
# [1206 rows x 9 columns]

# %%
modern_gallery[modern_gallery['Image_path'].isna()]
# Out:
# Empty DataFrame
# Columns: [Title, Artist, Nationality, Lifespan, Image_URL, Image_path, Birth, Death, Year]
# Index: []

# %% [markdown]
# ## 3. Create a new folder where only images included in the modern_gallery dataset are included, based on whether they have a valid filename

# %%
import shutil

# %%
# Define the source and destination directories
source_dir = 'artvee_downloads_all3'
destination_dir = 'modern_gallery_images'

unfound_images = []

# Ensure the destination directory exists
os.makedirs(destination_dir, exist_ok=True)

# Iterate over the rows in the modern_gallery DataFrame
for index, row in modern_gallery.iterrows():
    # Construct the full path to the source image file
    image_filename = row['Image_path']
    source_path = os.path.join(source_dir, image_filename)

    # Construct the full path to the destination file
    destination_path = os.path.join(destination_dir, image_filename)

    # Check if the file exists in the source directory
    if os.path.exists(source_path):
        # Move the file to the new directory
        shutil.move(source_path, destination_path)
    else:
        unfound_images.append(image_filename)
        print(f"File not found: {image_filename}")
# Out:
# File not found: Decoratief ontwerp (1874).jpg
# File not found: Decoratief ontwerp (1874).jpg
# File not found: Untitled (1900 - 1930).jpg
# File not found: Dancing Figure (1910 - 1915).jpg
# File not found: Schip op een werfhelling (1906).jpg
# File not found: Decoratief ontwerp (1874).jpg
# File not found: Štubnianske Teplice (1934–1935).jpg
# File not found: Designs for theater with black-framed proscenium and boldly colored settings.] [Study for stage light wall decoration, possibly for Caf ̌Crillon (277 Park Avenue) (1926).jpg
# File not found: Composition (1921).jpg
# File not found: Entwurf Zu ‘grüner Rand’ (Study For ‘green Border’) (1919).jpg
# File not found: Abstract design based on leaves and organic shapes (1900).jpg
# File not found: Abstract Nude (19th century).jpg
# File not found: Untitled (1938).jpg
# File not found: Head (before 1921).jpg

# %%
len(unfound_images)
# Out:
# 14

# %%
modern_gallery2 = modern_gallery[~modern_gallery['Image_path'].isin(unfound_images)]
modern_gallery2
# Out:
#                                                   Title  \
# 0                                          Construction
# 1     Dance Abstraction; Isadora Duncan (or ‘Rhythmi...
# 2                Ohne Titel; aus; ‘Die 150 Blätter’ VII
# 3                          Zeilboten op een werfhelling
# 4                                                   Why
# ...                                                 ...
# 1324                                          Periphery
# 1325  Váza s kyticí a broskve (Vase of flowers and p...
# 1326                                      Self-Portrait
# 1328                                       Klänge Pl.13
# 1329  Beethovenfries; ‘Die Sehnsucht nach Glück find...
#
#                      Artist Nationality      Lifespan  \
# 0        László Moholy-Nagy   Hungarian   1895 - 1946
# 1         Abraham Walkowitz    American     1878-1965
# 2               Karl Wiener    Austrian     1901-1949
# 3              Reijer Stolk       Dutch   1896 - 1945
# 4               Karl Wiener    Austrian     1901-1949
# ...                     ...         ...           ...
# 1324        Mikuláš Galanda      Slovak   1895 – 1938
# 1325             Emil Filla       Czech     1882-1953
# 1326  Ernst Ludwig Kirchner      German     1880-1938
# 1328      Wassily Kandinsky     Russian   1866 - 1944
# 1329           Gustav Klimt    Austrian     1862-1918
#
#                                    Image_URL  \
# 0     https://mdl.artvee.com/ft/101991ab.jpg
# 1     https://mdl.artvee.com/ft/106394ab.jpg
# 2     https://mdl.artvee.com/ft/104773ab.jpg
# 3     https://mdl.artvee.com/ft/103462ab.jpg
# 4     https://mdl.artvee.com/ft/104895ab.jpg
# ...                                      ...
# 1324  https://mdl.artvee.com/ft/101476ab.jpg
# 1325  https://mdl.artvee.com/ft/912315ab.jpg
# 1326  https://mdl.artvee.com/ft/100178ab.jpg
# 1328  https://mdl.artvee.com/ft/910880ab.jpg
# 1329  https://mdl.artvee.com/ft/105257ab.jpg
#
#                                              Image_path  Birth  Death  Year
# 0                               Construction (1924).jpg   1895   1946  1924
# 1     Dance Abstraction; Isadora Duncan (or ‘Rhythmi...   1878   1965  1920
# 2     Ohne Titel; aus; ‘Die 150 Blätter’ VII (1940).jpg   1901   1949  1940
# 3               Zeilboten op een werfhelling (1906).jpg   1896   1945  1906
# 4                                        Why (1940).jpg   1901   1949  1940
# ...                                                 ...    ...    ...   ...
# 1324                               Periphery (1924).jpg   1895   1938  1924
# 1325  Váza s kyticí a broskve (Vase of flowers and p...   1882   1953  1932
# 1326                           Self-Portrait (1928).jpg   1880   1938  1928
# 1328                            Klänge Pl.13 (1913).jpg   1866   1944  1913
# 1329  Beethovenfries; ‘Die Sehnsucht nach Glück find...   1862   1918  1901
#
# [1180 rows x 9 columns]

# %%
len(modern_gallery2)
# Out:
# 1180

# %% [markdown]
# ## 4. Remove Rows with Missing Data
#
# In my experience creating this data only the Year column had NA values

# %%
modern_gallery2[modern_gallery2['Year'].isna()]
# Out:
# Empty DataFrame
# Columns: [Title, Artist, Nationality, Lifespan, Image_URL, Image_path, Birth, Death, Year]
# Index: []

# %%
modern_gallery2 = modern_gallery2[~modern_gallery2['Year'].isna()]

# %%
#modern_gallery2.to_csv('modern_gallery.csv', index=False)

# %% [markdown]
# ## 5. Create live image links for each filepath based on github repository

# %%
image_directory = 'User/Documents/artvee_downloads_all3' #use your own local path!

# %% [markdown]
# Verify number of existing files:

# %%
# Count the number of files in the directory
file_count = len([f for f in os.listdir(image_directory) if os.path.isfile(os.path.join(image_directory, f))])

print(f"Number of files in the directory: {file_count}")

# %% [markdown]
# Function to verify a specific file exists:

# %%
def image_exists(image_path):
    return os.path.isfile(os.path.join(image_directory, image_path))

# %%
filtered_gallery = modern_gallery2[modern_gallery2['Image_path'].apply(image_exists)]

len(filtered_gallery)

# %% [markdown]
# ### Combine a github repository link with your image paths to create a live link
#
# ### This will work to host your images as weblinks for free assuming you have created a gituhub repository and uploaded your files with the filenames created in this notebook

# %%
base_url = 'https://raw.githubusercontent.com/Your_Github_Account/your_repository/main/'


# Create the full URL for each image and add it as a new column
filtered_gallery.loc[:, 'Image_URL'] = base_url + filtered_gallery['Image_path']

# %% [markdown]
# # Web links cannot have spaces! Replace spaces with their coded value %20

# %%
filtered_gallery['Image_URL'] = filtered_gallery['Image_URL'].str.replace(' ', '%20')

# %% [markdown]
# Save your final dataset:

# %%
#filtered_gallery.to_csv('modern_gallery.csv', index=False)
